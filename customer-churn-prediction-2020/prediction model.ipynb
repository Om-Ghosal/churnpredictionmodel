# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression,LogisticRegression
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler,LabelEncoder

# %%
le=LabelEncoder()
sc = StandardScaler()
data= pd.read_csv('train.csv')
data
# Out:
#      state  account_length      area_code international_plan voice_mail_plan  \
# 0       OH             107  area_code_415                 no             yes
# 1       NJ             137  area_code_415                 no              no
# 2       OH              84  area_code_408                yes              no
# 3       OK              75  area_code_415                yes              no
# 4       MA             121  area_code_510                 no             yes
# ...    ...             ...            ...                ...             ...
# 4245    MT              83  area_code_415                 no              no
# 4246    WV              73  area_code_408                 no              no
# 4247    NC              75  area_code_408                 no              no
# 4248    HI              50  area_code_408                 no             yes
# 4249    VT              86  area_code_415                 no             yes
#
# ...

# %%
list=['state','area_code','international_plan','voice_mail_plan','churn']
for l in list :
    temp = le.fit_transform(data[l])
    data.drop(l,axis=1,inplace=True)
    data[l]=temp
data.head(5)
# Out:
#    account_length  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0             107                     26              161.6              123
# 1             137                      0              243.4              114
# 2              84                      0              299.4               71
# 3              75                      0              166.7              113
# 4             121                     24              218.2               88
#
#    total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0             27.47              195.5              103             16.62
# 1             41.38              121.2              110             10.30
# 2             50.90               61.9               88              5.26
# 3             28.34              148.3              122             12.61
# 4             37.09              348.5              108             29.62
#
# ...

# %%
a=data.drop(['churn'],axis=1)
X=sc.fit_transform(a)
y=data['churn']

data
# Out:
#       account_length  number_vmail_messages  total_day_minutes  \
# 0                107                     26              161.6
# 1                137                      0              243.4
# 2                 84                      0              299.4
# 3                 75                      0              166.7
# 4                121                     24              218.2
# ...              ...                    ...                ...
# 4245              83                      0              188.3
# 4246              73                      0              177.9
# 4247              75                      0              170.7
# 4248              50                     40              235.7
# 4249              86                     34              129.4
#
#       total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# 0                 123             27.47              195.5              103
# ...

# %%
data_test = pd.read_csv("test.csv")


list=['state','area_code','international_plan','voice_mail_plan']
for l in list :
    temp = le.fit_transform(data_test[l])
    data_test.drop(l,axis=1,inplace=True)
    data_test[l]=temp
data_test.head(5)

X_test = sc.fit_transform(data_test.drop(['id'],axis=1))

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
#from sklearn.preproccesing import LinearScaler

o= LogisticRegression()
o.fit(X,y)
o.predict(X_test)

samp = pd.read_csv('sampleSubmission.csv')
list=['churn']
for l in list :
    temp = le.fit_transform(samp[l])
    samp.drop(l,axis=1,inplace=True)
    samp[l]=temp
samp.head(5)


y_test=samp.drop(['id'],axis=1)
o.score(X_test,y_test)
# Out:
# 0.5946666666666667
